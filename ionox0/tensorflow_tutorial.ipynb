# %%
import numpy as np
help("modules")
import tensorflow as tf

# Create 100 phony x, y data points in NumPy, y = x * 0.1 + 0.3
x_data = np.random.rand(100).astype(np.float32)
y_data = x_data * 0.1 + 0.3

# Try to find values for W and b that compute y_data = W * x_data + b
# (We know that W should be 0.1 and b 0.3, but TensorFlow will
# figure that out for us.)
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

# Minimize the mean squared errors.
loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# Before starting, initialize the variables.  We will 'run' this first.
init = tf.global_variables_initializer()

# Launch the graph.
sess = tf.Session()
sess.run(init)

# Fit the line.
for step in range(201):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(W), sess.run(b))

# Learns best fit is W: [0.1], b: [0.3]
# Out:
# Please wait a moment while I gather a list of all available modules...
# /Library/Python/2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# Using TensorFlow backend.
# /Library/Python/2.7/site-packages/skimage/filter/__init__.py:6: skimage_deprecation: The `skimage.filter` module has been renamed to `skimage.filters`.  This placeholder module will be removed in v0.13.
#   warn(skimage_deprecation('The `skimage.filter` module has been renamed '
# AVFoundation        _curses_panel       flask               py_compile
# Accounts            _elementtree        flask_login         pyclbr
# AddressBook         _functools          flask_sqlalchemy    pydoc
# AppKit              _hashlib            fnmatch             pydoc_data
# AppleScriptKit      _heapq              formatter           pyexpat
# AppleScriptObjC     _hotshot            fpformat            pygments
# Audio_mac           _io                 fractions           pylab
# Automator           _json               ftplib              pyparsing
# BaseHTTPServer      _locale             funcsigs            pytz
# Bastion             _lsprof             functools           pyximport
# CFNetwork           _multibytecodec     functools32         quopri
# CFOpenDirectory     _multiprocessing    future_builtins     random
# CGIHTTPServer       _osx_support        gc                  re
# Canvas              _pyio               genericpath         readline
# Carbon              _random             gensuitemodule      repr
# Cocoa               _scandir            geopy               requests
# CodeWarrior         _scproxy            gestalt             resource
# Collaboration       _socket             getopt              rexec
# ColorPicker         _sqlite3            getpass             rfc822
# ConfigParser        _sre                gettext             rlcompleter
# Cookie              _ssl                glob                rmagic
# CoreData            _strptime           grp                 robotparser
# CoreFoundation      _struct             gzip                runpy
# CoreGraphics        _symtable           hashlib             scandir
# CoreLocation        _sysconfigdata      heapq               sched
# CoreText            _testcapi           hmac                scipy
# Cython              _threading_local    hotshot             select
# Dialog              _tkinter            html5lib            selenium
# DictionaryServices  _warnings           htmlentitydefs      sets
# DocXMLRPCServer     _weakref            htmllib             setuptools
# EasyDialogs         _weakrefset         httplib             sgmllib
# EventKit            abc                 ic                  sha
# ExceptionHandling   aepack              icglue              shelve
# Explorer            aetools             icopen              shlex
# FSEvents            aetypes             idlelib             shutil
# FileDialog          aifc                ihooks              shutil_backports
# Finder              altgraph            imageop             signal
# FixTk               antigravity         imaplib             simplegeneric
# Foundation          anydbm              imghdr              singledispatch
# FrameWork           appdirs             imp                 singledispatch_helpers
# HTMLParser          appium              importlib           site
# IN                  applesingle         imputil             six
# IPython             appletrawmain       inspect             skimage
# InputMethodKit      appletrunner        io                  smtpd
# InstallerPlugins    appnope             ipykernel           smtplib
# InstantMessage      apscheduler         ipython_genutils    sndhdr
# JavaScriptCore      argparse            itertools           socket
# LatentSemanticMapping argvemulator        itsdangerous        sqlalchemy
# LaunchServices      array               jinja2              sqlite3
# MacOS               ast                 json                sre
# Message             asynchat            jsonschema          sre_compile
# MimeWriter          asyncore            jupyter             sre_constants
# MiniAEFrame         atexit              jupyter_client      sre_parse
# Nav                 audiodev            jupyter_contrib_core ssl
# Netscape            audioop             jupyter_contrib_nbextensions stat
# OSATerminology      autoGIL             jupyter_core        statvfs
# OpenDirectory       autoreload          jupyter_highlight_selected_word storemagic
# OpenSSL             backports           jupyter_nbextensions_configurator string
# PixMapWrapper       backports_abc       keras               stringold
# PreferencePanes     base64              keyword             stringprep
# PubSub              bdb                 latex_envs          strop
# PyObjCTools         bdist_mpkg          lib2to3             struct
# QTKit               bgenlocations       linecache           subprocess
# Quartz              binascii            locale              sunau
# Queue               binhex              logging             sunaudio
# ScreenSaver         bisect              macerrors           symbol
# ScriptingBridge     bleach              macholib            sympyprinting
# ScrolledText        bonjour             macostools          symtable
# SearchKit           boto                macpath             sys
# ServiceManagement   bottle              macresource         sysconfig
# SimpleDialog        bs4                 macurl2path         syslog
# SimpleHTTPServer    bsddb               mailbox             tabnanny
# SimpleITK           bsddb185            mailcap             tarfile
# SimpleXMLRPCServer  buildtools          markupbase          telnetlib
# Social              bundlebuilder       markupsafe          tempfile
# SocketServer        bz2                 marshal             terminado
# StdSuites           cPickle             marshmallow         terminalcommand
# StringIO            cProfile            math                termios
# SyncServices        cStringIO           matplotlib          test
# SystemConfiguration calendar            md5                 testpath
# SystemEvents        certifi             mhlib               tests
# Tix                 cfmfile             mimetools           textwrap
# Tkconstants         cgi                 mimetypes           theano
# Tkdnd               cgitb               mimify              this
# Tkinter             chunk               mistune             thread
# UserDict            click               mmap                threading
# UserList            cmath               mock                time
# UserString          cmd                 modulefinder        timeit
# VBoxPython2_5       code                modulegraph         tkColorChooser
# VBoxPython2_6       codecs              multifile           tkCommonDialog
# VBoxPython2_7       codeop              multiprocessing     tkFileDialog
# WebKit              collections         mutex               tkFont
# _AE                 colorsys            nbconvert           tkMessageBox
# _AH                 commands            nbformat            tkSimpleDialog
# _App                compileall          netrc               toaiff
# _CF                 compiler            networkx            token
# _CG                 concurrent          new                 tokenize
# _CarbonEvt          configparser        nis                 tornado
# _Cm                 contextlib          nntplib             trace
# _Ctl                cookielib           notebook            traceback
# _Dlg                copy                ntpath              traitlets
# _Drag               copy_reg            nturl2path          ttk
# _Evt                coverage            numbers             tty
# _File               crypt               numpy               turtle
# _Fm                 csv                 objc                twisted
# _Folder             ctypes              opcode              types
# _Help               curses              operator            tzlocal
# _IBCarbon           cython              optparse            unicodedata
# _Icn                cythonmagic         os                  unittest
# _LWPCookieJar       datetime            os2emxpath          urllib
# _Launch             dateutil            packaging           urllib2
# _List               dbhash              pandocfilters       urllib3
# _Menu               dbm                 parser              urlparse
# _Mlte               decimal             pathlib2            user
# _MozillaCookieJar   decorator           pbr                 uu
# _OSA                dicom               pdb                 uuid
# _Qd                 difflib             pexpect             vboxapi
# _Qdoffs             dircache            pickle              vboxshell
# _Qt                 dis                 pickleshare         videoreader
# _Res                distutils           pickletools         warnings
# _Scrap              django              pimp                wave
# _Snd                djorm_pgfulltext    pip                 wcwidth
# _TE                 djrill              pipes               weakref
# _Win                dl                  pkg_resources       webbrowser
# __builtin__         docopt              pkgutil             werkzeug
# __future__          doctest             platform            wheel
# _abcoll             dumbdbm             plistlib            whichdb
# _ast                dummy_thread        popen2              wsgiref
# _bisect             dummy_threading     poplib              xattr
# _builtinSuites      easy_install        posix               xdrlib
# _codecs             elasticsearch       posixfile           xml
# _codecs_cn          email               posixpath           xmllib
# _codecs_hk          encodings           pprint              xmlrpclib
# _codecs_iso2022     ensurepip           profile             xxsubtype
# _codecs_jp          entrypoints         prompt_toolkit      yaml
# _codecs_kr          enum                pstats              zipfile
# _codecs_tw          errno               psutil              zipimport
# _collections        exceptions          psycopg2            zlib
# _csv                fcntl               pty                 zmq
# _ctypes             filecmp             ptyprocess          zope
# _ctypes_test        fileinput           pwd
# _curses             findertools         py2app
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose descriptions contain the word "spam".
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-19c754c5efc9> in <module>()
#       1 import numpy as np
#       2 help("modules")
# ----> 3 import tensorflow as tf
#       4
#       5 # Create 100 phony x, y data points in NumPy, y = x * 0.1 + 0.3
#
# ImportError: No module named tensorflow
