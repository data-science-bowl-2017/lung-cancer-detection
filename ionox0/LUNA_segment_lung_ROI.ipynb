# %%
import numpy as np
from skimage import morphology
from skimage import measure
from sklearn.cluster import KMeans
from skimage.transform import resize
from glob import glob
import matplotlib.pyplot as plt

working_path = "./"
orig_images_file_list = glob(working_path+"luna_images/*.npy")

# %%
# View first image #
file = orig_images_file_list[0]
print file

imgs_to_process = np.load(file).astype(np.float64)
img = imgs_to_process[0]
plt.imshow(img)
plt.show()

mean = np.mean(img)
std = np.std(img) + .0000000001
img = img-mean
img = img/std
plt.imshow(img, cmap='gray')
plt.show()

middle = img[100:400,100:400] 
mean = np.mean(middle)  
max = np.max(img)
min = np.min(img)
# To improve threshold finding, I'm moving the 
# underflow and overflow on the pixel spectrum
img[img==max]=mean
img[img==min]=mean
plt.imshow(img)
plt.show()
# Out:
# ./luna_images/images_0001_0036.npy

# %%
for img_file in orig_images_file_list:
    # I ran into an error when using Kmean on np.float16, so I'm using np.float64 here
    imgs_to_process = np.load(img_file).astype(np.float64)
    
    for i in range(len(imgs_to_process)):
        img = imgs_to_process[i]
        
        #Standardize the pixel values
        mean = np.mean(img)
        std = np.std(img) + .0000000001
        img = img-mean
        img = img/std
        
        # Find the average pixel value near the lungs
        # to renormalize washed out images
        middle = img[100:400,100:400] 
        mean = np.mean(middle)  
        max = np.max(img)
        min = np.min(img)
        
        # To improve threshold finding, I'm moving the 
        # underflow and overflow on the pixel spectrum
        img[img==max]=mean
        img[img==min]=mean
        
        # Using Kmeans to separate foreground (radio-opaque tissue)
        # and background (radio transparent tissue ie lungs)
        # Doing this only on the center of the image to avoid 
        # the non-tissue parts of the image as much as possible
        kmeans = KMeans(n_clusters=2).fit(np.reshape(middle,[np.prod(middle.shape),1]))
        centers = sorted(kmeans.cluster_centers_.flatten())
        threshold = np.mean(centers)
        thresh_img = np.where(img<threshold,1.0,0.0)  # threshold the image
        
        # I found an initial erosion helful for removing graininess from some of the regions
        # and then large dialation is used to make the lung region 
        # engulf the vessels and incursions into the lung cavity by 
        # radio opaque tissue
        eroded = morphology.erosion(thresh_img,np.ones([4,4]))
        dilation = morphology.dilation(eroded,np.ones([10,10]))
        
        #  Label each region and obtain the region properties.
        #  The background region is removed by removing regions 
        #  with a bbox that is too large in either dimension
        #  Also, the lungs are generally far away from the top 
        #  and bottom of the image, so any regions that are too
        #  close to the top and bottom are removed
        #  This does not produce a perfect segmentation of the lungs
        #  from the image, but it is surprisingly good considering its
        #  simplicity.
        labels = measure.label(dilation)
        label_vals = np.unique(labels)
        regions = measure.regionprops(labels)
        good_labels = []
        for prop in regions:
            B = prop.bbox
            print(B)
            if B[2]-B[0]<475 and B[3]-B[1]<475 and B[0]>40 and B[2]<472:
                good_labels.append(prop.label)
        mask = np.ndarray([512,512],dtype=np.int8)
        mask[:] = 0
        
        #  The mask here is the mask for the lungs--not the nodes
        #  After just the lungs are left, we do another large dilation
        #  in order to fill in and out the lung mask
        for N in good_labels:
            mask = mask + np.where(labels==N,1,0)
        mask = morphology.dilation(mask,np.ones([10,10])) # one last dilation
        imgs_to_process[i] = mask
        
    np.save('./luna_images/new_mask_' + img_file.split('/')[-1], imgs_to_process)
# Out:
# (0L, 0L, 512L, 512L)
# (170L, 102L, 350L, 262L)
# (176L, 263L, 359L, 390L)
# (0L, 0L, 512L, 512L)
# (172L, 105L, 349L, 261L)
# (178L, 263L, 357L, 389L)
# (0L, 0L, 512L, 512L)
# (175L, 107L, 348L, 261L)
# (180L, 262L, 355L, 388L)
# (0L, 0L, 512L, 512L)
# (154L, 93L, 357L, 267L)
# (159L, 265L, 369L, 402L)
# (0L, 0L, 512L, 512L)
# (160L, 96L, 356L, 265L)
# (162L, 265L, 368L, 400L)
# (0L, 0L, 512L, 512L)
# (162L, 97L, 355L, 261L)
# (164L, 265L, 366L, 399L)
# (254L, 226L, 282L, 264L)
# (0L, 0L, 512L, 512L)
# (178L, 110L, 346L, 261L)
# (183L, 261L, 353L, 386L)
# (0L, 0L, 512L, 512L)
# (181L, 113L, 344L, 262L)
# (187L, 261L, 351L, 385L)
# (0L, 0L, 512L, 512L)
# (185L, 115L, 341L, 262L)
# (194L, 261L, 348L, 382L)
# (0L, 0L, 512L, 512L)
# (136L, 73L, 376L, 267L)
# (145L, 266L, 385L, 428L)
# (0L, 0L, 512L, 512L)
# (135L, 73L, 375L, 268L)
# (144L, 266L, 384L, 426L)
# (0L, 0L, 512L, 512L)
# (135L, 73L, 373L, 269L)
# (144L, 266L, 383L, 425L)
# (0L, 0L, 512L, 512L)
# (134L, 67L, 379L, 261L)
# (150L, 268L, 388L, 433L)
# (0L, 0L, 512L, 512L)
# (136L, 67L, 378L, 261L)
# (149L, 268L, 388L, 433L)
# (0L, 0L, 512L, 512L)
# (137L, 69L, 377L, 261L)
# (148L, 268L, 389L, 433L)
# (0L, 0L, 512L, 512L)
# (175L, 107L, 348L, 261L)
# (180L, 262L, 355L, 388L)
# (0L, 0L, 512L, 512L)
# (178L, 110L, 346L, 261L)
# (183L, 261L, 353L, 386L)
# (0L, 0L, 512L, 512L)
# (181L, 113L, 344L, 262L)
# (187L, 261L, 351L, 385L)
# (0L, 0L, 512L, 512L)
# (166L, 98L, 352L, 257L)
# (169L, 265L, 360L, 395L)
# (252L, 230L, 282L, 263L)
# (0L, 0L, 512L, 512L)
# (168L, 100L, 350L, 255L)
# (173L, 264L, 360L, 392L)
# (251L, 231L, 281L, 262L)
# (0L, 0L, 512L, 512L)
# (170L, 102L, 350L, 262L)
# (176L, 263L, 359L, 390L)
# (0L, 0L, 512L, 512L)
# (138L, 75L, 368L, 270L)
# (145L, 266L, 382L, 421L)
# (0L, 0L, 512L, 512L)
# (141L, 76L, 368L, 270L)
# (146L, 266L, 382L, 420L)
# (0L, 0L, 512L, 512L)
# (143L, 78L, 369L, 270L)
# (147L, 266L, 381L, 419L)
# (0L, 0L, 224L, 498L)
# (219L, 138L, 365L, 292L)
# (219L, 284L, 352L, 405L)
# (405L, 63L, 512L, 461L)
# (0L, 0L, 224L, 498L)
# (219L, 139L, 364L, 292L)
# (220L, 284L, 351L, 404L)
# (405L, 64L, 512L, 461L)
# (0L, 0L, 226L, 498L)
# (219L, 140L, 363L, 292L)
# (221L, 285L, 350L, 402L)
# (405L, 64L, 512L, 461L)
# (0L, 0L, 233L, 512L)
# (174L, 115L, 380L, 425L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 233L, 512L)
# (176L, 116L, 379L, 424L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 497L)
# (178L, 116L, 379L, 423L)
# (416L, 61L, 512L, 446L)
# (0L, 0L, 230L, 512L)
# (132L, 48L, 423L, 431L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (133L, 49L, 422L, 431L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (133L, 49L, 422L, 431L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 197L, 512L)
# (75L, 44L, 447L, 476L)
# (402L, 0L, 512L, 222L)
# (415L, 298L, 512L, 512L)
# (0L, 0L, 198L, 512L)
# (75L, 44L, 447L, 476L)
# (246L, 198L, 261L, 215L)
# (403L, 0L, 512L, 221L)
# (415L, 298L, 512L, 512L)
# (0L, 0L, 198L, 512L)
# (76L, 45L, 447L, 476L)
# (247L, 200L, 259L, 213L)
# (404L, 0L, 512L, 220L)
# (416L, 298L, 512L, 512L)
# (0L, 0L, 187L, 512L)
# (74L, 278L, 446L, 484L)
# (84L, 36L, 445L, 273L)
# (366L, 0L, 512L, 207L)
# (388L, 303L, 512L, 512L)
# (0L, 0L, 187L, 512L)
# (75L, 277L, 447L, 484L)
# (84L, 36L, 446L, 274L)
# (366L, 0L, 512L, 207L)
# (388L, 304L, 512L, 512L)
# (0L, 0L, 187L, 512L)
# (75L, 276L, 447L, 484L)
# (85L, 36L, 446L, 274L)
# (366L, 0L, 512L, 207L)
# (389L, 304L, 512L, 512L)
# (0L, 0L, 246L, 512L)
# (221L, 273L, 354L, 378L)
# (236L, 248L, 265L, 267L)
# (241L, 153L, 359L, 272L)
# (251L, 0L, 261L, 5L)
# (423L, 0L, 512L, 512L)
# (0L, 0L, 255L, 512L)
# (224L, 274L, 353L, 375L)
# (237L, 253L, 248L, 264L)
# (242L, 155L, 357L, 273L)
# (249L, 246L, 268L, 266L)
# (423L, 0L, 512L, 512L)
# (0L, 0L, 261L, 512L)
# (225L, 275L, 352L, 374L)
# (240L, 247L, 268L, 265L)
# (243L, 157L, 354L, 272L)
# (422L, 0L, 512L, 512L)
# (0L, 0L, 188L, 512L)
# (75L, 276L, 447L, 483L)
# (84L, 37L, 446L, 274L)
# (367L, 0L, 512L, 209L)
# (389L, 302L, 512L, 512L)
# (0L, 0L, 188L, 512L)
# (75L, 277L, 448L, 483L)
# (84L, 38L, 446L, 274L)
# (368L, 0L, 512L, 208L)
# (390L, 300L, 512L, 512L)
# (0L, 0L, 188L, 512L)
# (76L, 276L, 448L, 483L)
# (83L, 38L, 446L, 274L)
# (368L, 0L, 512L, 208L)
# (390L, 298L, 512L, 512L)
# (0L, 0L, 255L, 512L)
# (126L, 76L, 411L, 446L)
# (427L, 0L, 512L, 512L)
# (0L, 0L, 255L, 512L)
# (126L, 77L, 410L, 446L)
# (427L, 0L, 512L, 512L)
# (0L, 0L, 255L, 512L)
# (127L, 77L, 410L, 445L)
# (427L, 0L, 512L, 512L)
# (0L, 0L, 512L, 512L)
# (121L, 290L, 388L, 452L)
# (125L, 73L, 386L, 262L)
# (0L, 0L, 512L, 512L)
# (121L, 290L, 388L, 452L)
# (124L, 73L, 386L, 262L)
# (0L, 0L, 512L, 512L)
# (122L, 290L, 389L, 452L)
# (124L, 73L, 385L, 262L)
# (0L, 0L, 236L, 509L)
# (201L, 135L, 341L, 287L)
# (233L, 285L, 343L, 388L)
# (248L, 41L, 277L, 97L)
# (400L, 45L, 512L, 459L)
# (0L, 0L, 235L, 509L)
# (200L, 138L, 340L, 290L)
# (235L, 285L, 341L, 386L)
# (248L, 35L, 278L, 95L)
# (399L, 45L, 512L, 459L)
# (0L, 0L, 235L, 509L)
# (200L, 140L, 339L, 290L)
# (237L, 286L, 337L, 383L)
# (248L, 34L, 277L, 93L)
# (397L, 43L, 512L, 461L)
# (0L, 0L, 512L, 512L)
# (103L, 266L, 148L, 319L)
# (162L, 79L, 402L, 266L)
# (191L, 293L, 397L, 456L)
# (0L, 0L, 512L, 512L)
# (107L, 272L, 145L, 308L)
# (160L, 80L, 403L, 267L)
# (193L, 293L, 398L, 456L)
# (0L, 0L, 512L, 512L)
# (114L, 280L, 131L, 298L)
# (158L, 81L, 403L, 267L)
# (197L, 294L, 398L, 456L)
# (0L, 0L, 512L, 512L)
# (109L, 44L, 406L, 252L)
# (113L, 291L, 128L, 331L)
# (113L, 241L, 406L, 429L)
# (0L, 0L, 512L, 512L)
# (110L, 44L, 406L, 254L)
# (113L, 288L, 129L, 330L)
# (114L, 241L, 405L, 428L)
# (0L, 0L, 512L, 512L)
# (110L, 44L, 406L, 257L)
# (113L, 286L, 131L, 330L)
# (115L, 241L, 405L, 428L)
# (0L, 0L, 512L, 512L)
# (194L, 272L, 390L, 406L)
# (196L, 96L, 384L, 267L)
# (0L, 0L, 512L, 512L)
# (197L, 273L, 389L, 405L)
# (198L, 97L, 383L, 266L)
# (0L, 0L, 512L, 512L)
# (200L, 99L, 382L, 266L)
# (201L, 274L, 388L, 403L)
# (0L, 11L, 175L, 497L)
# (202L, 122L, 356L, 270L)
# (207L, 281L, 346L, 398L)
# (387L, 42L, 512L, 474L)
# (0L, 11L, 175L, 497L)
# (203L, 123L, 355L, 271L)
# (209L, 281L, 345L, 396L)
# (387L, 40L, 512L, 474L)
# (0L, 11L, 175L, 497L)
# (205L, 124L, 354L, 271L)
# (210L, 281L, 343L, 395L)
# (386L, 40L, 512L, 474L)
# (0L, 0L, 242L, 512L)
# (78L, 42L, 395L, 263L)
# (130L, 283L, 390L, 454L)
# (235L, 506L, 247L, 512L)
# (310L, 0L, 512L, 512L)
# (312L, 506L, 323L, 512L)
# (0L, 0L, 243L, 512L)
# (78L, 43L, 395L, 263L)
# (130L, 283L, 390L, 454L)
# (232L, 505L, 247L, 512L)
# (312L, 0L, 512L, 512L)
# (0L, 0L, 244L, 512L)
# (78L, 43L, 395L, 264L)
# (130L, 283L, 390L, 453L)
# (232L, 506L, 246L, 512L)
# (313L, 0L, 512L, 512L)
# (315L, 506L, 327L, 512L)
# (0L, 0L, 243L, 512L)
# (87L, 64L, 393L, 253L)
# (87L, 282L, 387L, 439L)
# (221L, 505L, 232L, 512L)
# (358L, 0L, 512L, 512L)
# (0L, 0L, 243L, 512L)
# (86L, 282L, 386L, 438L)
# (87L, 65L, 393L, 254L)
# (359L, 0L, 512L, 512L)
# (0L, 0L, 243L, 512L)
# (87L, 65L, 393L, 255L)
# (87L, 282L, 386L, 438L)
# (360L, 0L, 512L, 512L)
# (0L, 0L, 273L, 512L)
# (177L, 91L, 403L, 425L)
# (280L, 0L, 512L, 512L)
# (293L, 273L, 312L, 297L)
# (0L, 0L, 272L, 512L)
# (177L, 93L, 403L, 425L)
# (280L, 0L, 512L, 512L)
# (293L, 270L, 312L, 294L)
# (0L, 0L, 272L, 512L)
# (177L, 95L, 402L, 425L)
# (280L, 0L, 512L, 512L)
# (293L, 268L, 311L, 292L)
# (0L, 0L, 267L, 512L)
# (182L, 259L, 397L, 421L)
# (184L, 99L, 393L, 257L)
# (280L, 0L, 512L, 512L)
# (287L, 258L, 310L, 282L)
# (0L, 0L, 267L, 512L)
# (184L, 100L, 393L, 282L)
# (184L, 260L, 397L, 421L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 267L, 512L)
# (185L, 101L, 392L, 280L)
# (186L, 260L, 397L, 420L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 267L, 512L)
# (184L, 100L, 393L, 282L)
# (184L, 260L, 397L, 421L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 267L, 512L)
# (185L, 101L, 392L, 280L)
# (186L, 260L, 397L, 420L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 267L, 512L)
# (186L, 102L, 392L, 280L)
# (188L, 260L, 397L, 419L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 512L, 512L)
# (145L, 92L, 411L, 274L)
# (174L, 283L, 409L, 412L)
# (0L, 0L, 512L, 512L)
# (146L, 92L, 411L, 274L)
# (173L, 282L, 409L, 411L)
# (0L, 0L, 512L, 512L)
# (146L, 92L, 411L, 274L)
# (173L, 284L, 409L, 411L)
# (0L, 0L, 512L, 512L)
# (161L, 96L, 387L, 271L)
# (167L, 267L, 399L, 424L)
# (0L, 0L, 512L, 512L)
# (161L, 96L, 385L, 272L)
# (168L, 276L, 398L, 424L)
# (291L, 264L, 315L, 300L)
# (0L, 0L, 512L, 512L)
# (162L, 96L, 385L, 271L)
# (168L, 277L, 398L, 423L)
# (290L, 260L, 313L, 294L)
# (0L, 0L, 512L, 512L)
# (243L, 120L, 425L, 252L)
# (250L, 258L, 429L, 378L)
# (0L, 0L, 512L, 512L)
# (246L, 121L, 419L, 251L)
# (255L, 260L, 427L, 377L)
# (0L, 0L, 512L, 512L)
# (249L, 122L, 419L, 251L)
# (258L, 263L, 426L, 376L)
# (0L, 0L, 250L, 512L)
# (105L, 65L, 428L, 450L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 250L, 512L)
# (105L, 65L, 428L, 450L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 249L, 512L)
# (105L, 65L, 428L, 450L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 248L, 512L)
# (106L, 66L, 428L, 450L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 247L, 512L)
# (106L, 66L, 428L, 449L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 247L, 512L)
# (106L, 66L, 429L, 449L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 206L, 512L)
# (117L, 45L, 388L, 271L)
# (122L, 282L, 401L, 468L)
# (406L, 0L, 512L, 512L)
# (0L, 0L, 206L, 512L)
# (117L, 45L, 388L, 271L)
# (122L, 282L, 401L, 468L)
# (407L, 0L, 512L, 512L)
# (0L, 0L, 206L, 512L)
# (117L, 45L, 388L, 270L)
# (123L, 282L, 401L, 468L)
# (400L, 0L, 512L, 512L)
# (0L, 132L, 61L, 409L)
# (118L, 47L, 387L, 228L)
# (171L, 273L, 396L, 452L)
# (448L, 91L, 512L, 397L)
# (0L, 132L, 61L, 409L)
# (118L, 47L, 387L, 228L)
# (171L, 273L, 396L, 451L)
# (448L, 91L, 512L, 397L)
# (0L, 132L, 61L, 409L)
# (118L, 47L, 386L, 228L)
# (171L, 273L, 396L, 451L)
# (448L, 92L, 512L, 395L)
# (0L, 0L, 512L, 512L)
# (217L, 96L, 435L, 423L)
# (0L, 0L, 512L, 512L)
# (218L, 97L, 411L, 255L)
# (227L, 250L, 435L, 422L)
# (0L, 0L, 512L, 512L)
# (219L, 97L, 411L, 254L)
# (227L, 251L, 435L, 422L)
# (0L, 0L, 512L, 512L)
# (196L, 85L, 422L, 288L)
# (203L, 266L, 443L, 440L)
# (0L, 0L, 512L, 512L)
# (196L, 85L, 422L, 288L)
# (203L, 266L, 443L, 440L)
# (0L, 0L, 512L, 512L)
# (196L, 85L, 422L, 287L)
# (203L, 265L, 443L, 439L)
# (0L, 10L, 236L, 512L)
# (209L, 101L, 353L, 261L)
# (210L, 256L, 368L, 408L)
# (410L, 54L, 512L, 440L)
# (0L, 10L, 235L, 512L)
# (211L, 102L, 352L, 261L)
# (211L, 256L, 367L, 408L)
# (410L, 53L, 512L, 440L)
# (0L, 10L, 235L, 512L)
# (211L, 256L, 366L, 407L)
# (212L, 103L, 351L, 261L)
# (250L, 419L, 260L, 430L)
# (410L, 53L, 512L, 440L)
# (0L, 0L, 512L, 512L)
# (204L, 274L, 353L, 407L)
# (205L, 115L, 359L, 270L)
# (0L, 0L, 512L, 512L)
# (208L, 272L, 352L, 405L)
# (212L, 116L, 357L, 271L)
# (0L, 0L, 512L, 512L)
# (213L, 271L, 350L, 404L)
# (218L, 118L, 356L, 271L)
# (0L, 0L, 512L, 512L)
# (151L, 258L, 367L, 430L)
# (158L, 58L, 378L, 255L)
# (0L, 0L, 512L, 512L)
# (151L, 258L, 368L, 429L)
# (157L, 58L, 378L, 257L)
# (0L, 0L, 512L, 512L)
# (152L, 59L, 378L, 429L)
# (0L, 0L, 512L, 512L)
# (155L, 62L, 378L, 430L)
# (0L, 0L, 512L, 512L)
# (156L, 63L, 378L, 430L)
# (0L, 0L, 512L, 512L)
# (156L, 64L, 378L, 430L)
# (0L, 0L, 512L, 512L)
# (169L, 83L, 373L, 424L)
# (0L, 0L, 512L, 512L)
# (170L, 84L, 373L, 424L)
# (0L, 0L, 512L, 512L)
# (171L, 85L, 372L, 424L)
# (0L, 0L, 512L, 512L)
# (182L, 93L, 362L, 265L)
# (183L, 249L, 366L, 417L)
# (0L, 0L, 512L, 512L)
# (184L, 94L, 361L, 265L)
# (185L, 249L, 365L, 415L)
# (0L, 0L, 512L, 512L)
# (185L, 94L, 361L, 265L)
# (186L, 250L, 363L, 414L)
# (0L, 0L, 512L, 512L)
# (184L, 94L, 361L, 265L)
# (185L, 249L, 365L, 415L)
# (0L, 0L, 512L, 512L)
# (185L, 94L, 361L, 265L)
# (186L, 250L, 363L, 414L)
# (0L, 0L, 512L, 512L)
# (186L, 95L, 360L, 266L)
# (188L, 251L, 362L, 413L)
# (0L, 0L, 512L, 512L)
# (186L, 95L, 360L, 266L)
# (188L, 251L, 362L, 413L)
# (0L, 0L, 512L, 512L)
# (187L, 95L, 360L, 267L)
# (190L, 252L, 361L, 412L)
# (0L, 0L, 512L, 512L)
# (188L, 97L, 360L, 269L)
# (192L, 254L, 359L, 411L)
# (0L, 0L, 512L, 512L)
# (156L, 68L, 377L, 431L)
# (0L, 0L, 512L, 512L)
# (156L, 69L, 377L, 431L)
# (0L, 0L, 512L, 512L)
# (157L, 69L, 377L, 430L)
# (0L, 0L, 512L, 512L)
# (156L, 66L, 378L, 431L)
# (0L, 0L, 512L, 512L)
# (156L, 66L, 378L, 432L)
# (0L, 0L, 512L, 512L)
# (156L, 66L, 378L, 432L)
# (0L, 0L, 512L, 512L)
# (151L, 260L, 365L, 430L)
# (157L, 56L, 378L, 243L)
# (0L, 0L, 512L, 512L)
# (151L, 260L, 365L, 430L)
# (157L, 56L, 378L, 249L)
# (0L, 0L, 512L, 512L)
# (151L, 259L, 366L, 430L)
# (157L, 57L, 378L, 251L)
# (0L, 0L, 261L, 512L)
# (106L, 243L, 384L, 431L)
# (115L, 67L, 387L, 270L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 260L, 512L)
# (107L, 243L, 384L, 431L)
# (116L, 67L, 387L, 270L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 260L, 512L)
# (107L, 243L, 384L, 431L)
# (117L, 67L, 387L, 269L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 193L, 512L)
# (126L, 70L, 370L, 447L)
# (321L, 0L, 512L, 512L)
# (0L, 0L, 193L, 512L)
# (129L, 72L, 367L, 446L)
# (322L, 0L, 512L, 512L)
# (0L, 0L, 192L, 512L)
# (133L, 74L, 365L, 446L)
# (323L, 0L, 512L, 512L)
# (0L, 3L, 221L, 511L)
# (233L, 280L, 358L, 385L)
# (245L, 149L, 354L, 262L)
# (391L, 40L, 484L, 471L)
# (484L, 150L, 512L, 357L)
# (0L, 3L, 221L, 511L)
# (237L, 278L, 357L, 383L)
# (246L, 149L, 353L, 262L)
# (391L, 40L, 484L, 471L)
# (484L, 150L, 512L, 357L)
# (0L, 3L, 221L, 511L)
# (238L, 277L, 355L, 381L)
# (247L, 151L, 353L, 263L)
# (390L, 39L, 484L, 471L)
# (484L, 150L, 512L, 357L)
# (0L, 79L, 84L, 441L)
# (146L, 101L, 380L, 249L)
# (203L, 291L, 383L, 429L)
# (222L, 0L, 254L, 22L)
# (263L, 5L, 336L, 41L)
# (401L, 46L, 479L, 462L)
# (487L, 158L, 512L, 350L)
# (0L, 78L, 85L, 442L)
# (147L, 102L, 385L, 249L)
# (201L, 292L, 386L, 428L)
# (221L, 0L, 242L, 19L)
# (263L, 4L, 335L, 42L)
# (402L, 47L, 479L, 462L)
# (487L, 158L, 512L, 350L)
# (0L, 78L, 85L, 443L)
# (147L, 102L, 388L, 249L)
# (198L, 292L, 386L, 427L)
# (221L, 0L, 239L, 18L)
# (263L, 25L, 306L, 41L)
# (310L, 4L, 335L, 25L)
# (403L, 48L, 479L, 462L)
# (487L, 158L, 512L, 350L)
# (0L, 0L, 315L, 491L)
# (123L, 46L, 429L, 285L)
# (130L, 287L, 438L, 479L)
# (341L, 13L, 510L, 420L)
# (0L, 0L, 311L, 488L)
# (123L, 46L, 429L, 289L)
# (129L, 287L, 438L, 479L)
# (346L, 15L, 510L, 419L)
# (0L, 0L, 311L, 487L)
# (123L, 47L, 429L, 291L)
# (128L, 287L, 438L, 480L)
# (351L, 17L, 510L, 419L)
# (0L, 0L, 512L, 512L)
# (178L, 102L, 392L, 459L)
# (0L, 0L, 512L, 512L)
# (180L, 102L, 392L, 458L)
# (0L, 0L, 512L, 512L)
# (181L, 102L, 391L, 457L)
# (0L, 0L, 488L, 512L)
# (148L, 75L, 413L, 258L)
# (154L, 288L, 416L, 460L)
# (436L, 0L, 512L, 512L)
# (0L, 0L, 488L, 512L)
# (148L, 75L, 413L, 260L)
# (153L, 289L, 415L, 460L)
# (436L, 0L, 512L, 512L)
# (0L, 0L, 488L, 512L)
# (148L, 75L, 413L, 261L)
# (153L, 289L, 415L, 460L)
# (436L, 0L, 512L, 512L)
# (0L, 0L, 188L, 512L)
# (122L, 69L, 376L, 274L)
# (126L, 288L, 381L, 452L)
# (263L, 277L, 286L, 314L)
# (372L, 0L, 512L, 512L)
# (0L, 0L, 188L, 512L)
# (123L, 70L, 375L, 274L)
# (126L, 288L, 380L, 452L)
# (262L, 275L, 286L, 311L)
# (371L, 0L, 512L, 512L)
# (0L, 0L, 31L, 13L)
# (0L, 27L, 13L, 38L)
# (0L, 39L, 19L, 61L)
# (0L, 208L, 5L, 218L)
# (0L, 295L, 6L, 316L)
# (10L, 303L, 24L, 320L)
# (11L, 444L, 22L, 454L)
# (13L, 496L, 23L, 506L)
# (20L, 13L, 39L, 25L)
# (24L, 204L, 91L, 370L)
# (38L, 132L, 55L, 162L)
# (48L, 371L, 60L, 384L)
# (56L, 167L, 70L, 197L)
# (60L, 201L, 74L, 212L)
# (61L, 20L, 123L, 122L)
# (69L, 411L, 83L, 439L)
# (72L, 483L, 86L, 498L)
# (87L, 481L, 97L, 491L)
# (123L, 70L, 375L, 274L)
# (124L, 502L, 139L, 512L)
# (126L, 287L, 380L, 451L)
# (148L, 0L, 188L, 22L)
# (256L, 225L, 271L, 238L)
# (263L, 273L, 279L, 286L)
# (267L, 291L, 285L, 308L)
# (371L, 0L, 512L, 512L)
# (502L, 301L, 512L, 329L)
# (504L, 273L, 512L, 284L)
# (505L, 226L, 512L, 247L)
# (0L, 0L, 512L, 512L)
# (97L, 87L, 336L, 415L)
# (0L, 0L, 512L, 512L)
# (97L, 87L, 336L, 415L)
# (0L, 0L, 512L, 512L)
# (97L, 87L, 336L, 415L)
# (0L, 0L, 237L, 512L)
# (107L, 94L, 323L, 405L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 236L, 512L)
# (108L, 255L, 322L, 404L)
# (111L, 95L, 306L, 253L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 235L, 512L)
# (109L, 255L, 322L, 404L)
# (111L, 95L, 306L, 253L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 256L, 512L)
# (214L, 96L, 407L, 266L)
# (214L, 283L, 399L, 407L)
# (422L, 0L, 512L, 512L)
# (0L, 0L, 260L, 512L)
# (215L, 97L, 406L, 267L)
# (218L, 283L, 399L, 406L)
# (427L, 0L, 512L, 512L)
# (0L, 0L, 260L, 512L)
# (216L, 98L, 406L, 266L)
# (218L, 283L, 399L, 406L)
# (422L, 0L, 512L, 512L)
# (0L, 0L, 180L, 512L)
# (90L, 32L, 446L, 488L)
# (424L, 0L, 512L, 512L)
# (0L, 0L, 180L, 512L)
# (92L, 32L, 432L, 275L)
# (108L, 276L, 446L, 488L)
# (424L, 0L, 512L, 512L)
# (0L, 0L, 181L, 512L)
# (94L, 32L, 446L, 487L)
# (425L, 0L, 512L, 512L)
# (0L, 0L, 180L, 512L)
# (92L, 32L, 432L, 275L)
# (108L, 276L, 446L, 488L)
# (424L, 0L, 512L, 512L)
# (0L, 0L, 181L, 512L)
# (94L, 32L, 446L, 487L)
# (425L, 0L, 512L, 512L)
# (0L, 0L, 182L, 512L)
# (96L, 32L, 446L, 487L)
# (425L, 0L, 512L, 512L)
# (0L, 0L, 183L, 512L)
# (99L, 33L, 446L, 486L)
# (425L, 0L, 512L, 512L)
# (0L, 0L, 184L, 512L)
# (101L, 33L, 445L, 486L)
# (425L, 0L, 512L, 512L)
# (0L, 0L, 184L, 512L)
# (102L, 34L, 444L, 485L)
# (425L, 0L, 512L, 512L)
# (0L, 0L, 188L, 512L)
# (107L, 38L, 441L, 481L)
# (426L, 0L, 512L, 512L)
# (0L, 0L, 189L, 512L)
# (108L, 38L, 441L, 482L)
# (426L, 0L, 512L, 512L)
# (0L, 0L, 191L, 512L)
# (109L, 38L, 441L, 482L)
# (425L, 0L, 512L, 512L)
# (0L, 0L, 187L, 512L)
# (106L, 37L, 442L, 481L)
# (425L, 0L, 512L, 512L)
# (0L, 0L, 188L, 512L)
# (107L, 38L, 441L, 481L)
# (426L, 0L, 512L, 512L)
# (0L, 0L, 189L, 512L)
# (108L, 38L, 441L, 482L)
# (426L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (78L, 282L, 388L, 436L)
# (82L, 70L, 393L, 257L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (78L, 282L, 389L, 436L)
# (82L, 71L, 394L, 257L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (79L, 282L, 389L, 435L)
# (83L, 74L, 395L, 256L)
# (280L, 0L, 512L, 512L)
# (0L, 110L, 48L, 372L)
# (78L, 60L, 392L, 264L)
# (116L, 31L, 131L, 44L)
# (134L, 284L, 387L, 447L)
# (384L, 38L, 512L, 476L)
# (0L, 104L, 52L, 376L)
# (78L, 60L, 393L, 264L)
# (113L, 30L, 133L, 46L)
# (134L, 284L, 388L, 446L)
# (384L, 38L, 512L, 476L)
# (0L, 0L, 230L, 512L)
# (80L, 61L, 393L, 264L)
# (134L, 284L, 388L, 446L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (78L, 282L, 389L, 436L)
# (82L, 71L, 394L, 257L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (79L, 282L, 389L, 435L)
# (83L, 74L, 395L, 256L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (80L, 282L, 389L, 434L)
# (84L, 75L, 395L, 256L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 286L, 512L)
# (168L, 120L, 417L, 268L)
# (173L, 266L, 410L, 396L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 284L, 512L)
# (169L, 121L, 414L, 253L)
# (174L, 267L, 408L, 395L)
# (280L, 0L, 512L, 512L)
# (291L, 241L, 327L, 265L)
# (0L, 0L, 281L, 512L)
# (170L, 121L, 413L, 254L)
# (175L, 268L, 406L, 394L)
# (280L, 0L, 512L, 512L)
# (290L, 242L, 326L, 264L)
# (0L, 0L, 512L, 512L)
# (165L, 119L, 419L, 274L)
# (170L, 263L, 413L, 399L)
# (0L, 0L, 512L, 512L)
# (167L, 119L, 420L, 273L)
# (171L, 264L, 413L, 398L)
# (0L, 0L, 512L, 512L)
# (167L, 120L, 418L, 270L)
# (172L, 265L, 412L, 398L)
# (283L, 208L, 293L, 218L)
# (0L, 0L, 230L, 512L)
# (129L, 97L, 403L, 422L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (130L, 98L, 403L, 421L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 230L, 512L)
# (131L, 98L, 402L, 421L)
# (280L, 0L, 512L, 512L)
# (0L, 0L, 512L, 512L)
# (109L, 71L, 377L, 435L)
# (0L, 0L, 512L, 512L)
# (109L, 72L, 377L, 435L)
# (0L, 0L, 512L, 512L)
# (109L, 72L, 377L, 435L)
# (0L, 0L, 512L, 512L)
# (121L, 253L, 355L, 423L)
# (130L, 67L, 365L, 251L)
# (0L, 0L, 512L, 512L)
# (122L, 254L, 355L, 423L)
# (130L, 68L, 364L, 251L)
# (260L, 252L, 270L, 262L)
# (0L, 0L, 512L, 512L)
# (121L, 253L, 355L, 423L)
# (130L, 68L, 364L, 251L)
# (260L, 252L, 270L, 262L)
# (0L, 3L, 252L, 512L)
# (187L, 103L, 377L, 263L)
# (198L, 275L, 383L, 406L)
# (414L, 56L, 512L, 442L)
# (0L, 3L, 251L, 512L)
# (187L, 104L, 377L, 263L)
# (199L, 275L, 382L, 406L)
# (413L, 55L, 512L, 442L)
# (0L, 3L, 251L, 512L)
# (188L, 104L, 376L, 263L)
# (200L, 275L, 382L, 406L)
# (413L, 55L, 512L, 441L)

# %%
# Here we're applying the masks and cropping and resizing the image

masks_file_list = glob(working_path+"luna_images/new_mask_*.npy")
print(len(masks_file_list))

out_images = []      #final set of images
out_nodemasks = []   #final set of nodemasks
for fname in masks_file_list:
    print "working on file ", fname
    imgs_to_process = np.load(fname.replace("masks","images"))
    masks = np.load(fname)
    node_masks = np.load(fname.replace("lungmask","masks"))
    for i in range(len(imgs_to_process)):
        mask = masks[i]
        print(mask[mask!=0])
        node_mask = node_masks[i]
        img = imgs_to_process[i]
        new_size = [512,512]   # we're scaling back up to the original size of the image
        img= mask*img          # apply lung mask
        #
        # renormalizing the masked image (in the mask region)
        #
        new_mean = np.mean(img[mask>0])  
        new_std = np.std(img[mask>0])
        #
        #  Pulling the background color up to the lower end
        #  of the pixel range for the lungs
        #
        old_min = np.min(img)       # background color
        img[img==old_min] = new_mean-1.2*new_std   # resetting backgound color
        img = img-new_mean
        img = img/new_std
        #make image bounding box  (min row, min col, max row, max col)
        labels = measure.label(mask)
        regions = measure.regionprops(labels)
        print("Labels?: ", labels[labels!=0])
        print("Regions: ", regions)
        #
        # Finding the global min and max row over all regions
        #
        min_row = 512
        max_row = 0
        min_col = 512
        max_col = 0
        for prop in regions:
            B = prop.bbox
            if min_row > B[0]:
                min_row = B[0]
            if min_col > B[1]:
                min_col = B[1]
            if max_row < B[2]:
                max_row = B[2]
            if max_col < B[3]:
                max_col = B[3]
        width = max_col-min_col
        height = max_row - min_row
        if width > height:
            max_row=min_row+width
        else:
            max_col = min_col+height
        # 
        # cropping the image down to the bounding box for all regions
        # (there's probably an skimage command that can do this in one line)
        # 
        img  = img[min_row:max_row,min_col:max_col]
        mask = mask[min_row:max_row,min_col:max_col]
        if max_row-min_row <5 or max_col-min_col<5:  # skipping all images with no god regions
            print("no good regions")
            pass
        else:
            # moving range to -1 to 1 to accomodate the resize function
            mean = np.mean(img)
            img = img - mean
            min = np.min(img)
            max = np.max(img)
            img = img/(max-min)
            new_img = resize(img,[512,512])
            new_node_mask = resize(node_mask[min_row:max_row,min_col:max_col],[512,512])
            out_images.append(new_img)
            out_nodemasks.append(new_node_mask)
# Out:
# 144
# working on file  ./luna_images/new_mask_images_0001_0036.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x11962df90>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# working on file  ./luna_images/new_mask_images_0001_0037.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962d410>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0001_0038.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x11962d410>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0001_0039.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d490>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d8d0>])
# working on file  ./luna_images/new_mask_images_0001_0040.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d350>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d810>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d410>])
# working on file  ./luna_images/new_mask_images_0001_0041.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# working on file  ./luna_images/new_mask_images_0001_0042.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>])
# working on file  ./luna_images/new_mask_images_0001_0043.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d490>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d410>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# working on file  ./luna_images/new_mask_images_0002_0054.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0002_0055.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0003_0070.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0006_0090.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0006_0091.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0006_0092.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# working on file  ./luna_images/new_mask_images_0006_0093.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# working on file  ./luna_images/new_mask_images_0006_0094.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# working on file  ./luna_images/new_mask_images_0008_0127.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d350>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>])
# working on file  ./luna_images/new_mask_images_0008_0128.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d810>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d510>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d710>])
# working on file  ./luna_images/new_mask_images_0010_0140.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962dbd0>, <skimage.measure._regionprops._RegionProperties object at 0x11962d8d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>, <skimage.measure._regionprops._RegionProperties object at 0x11962d410>])
# working on file  ./luna_images/new_mask_images_0012_0151.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d8d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>])
# working on file  ./luna_images/new_mask_images_0015_0184.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d910>])
# working on file  ./luna_images/new_mask_images_0016_0198.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# working on file  ./luna_images/new_mask_images_0017_0233.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d350>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962d910>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962d710>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962d810>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# working on file  ./luna_images/new_mask_images_0017_0234.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d350>, <skimage.measure._regionprops._RegionProperties object at 0x11962dbd0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d810>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d8d0>])
# working on file  ./luna_images/new_mask_images_0018_0257.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# working on file  ./luna_images/new_mask_images_0018_0258.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0018_0259.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0019_0278.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d510>])
# working on file  ./luna_images/new_mask_images_0020_0280.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d490>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d8d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# working on file  ./luna_images/new_mask_images_0021_0298.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962dbd0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d510>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d410>])
# working on file  ./luna_images/new_mask_images_0023_0314.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0023_0315.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# working on file  ./luna_images/new_mask_images_0024_0337.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d910>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d490>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d710>])
# working on file  ./luna_images/new_mask_images_0025_0351.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962dbd0>])
# working on file  ./luna_images/new_mask_images_0026_0352.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# working on file  ./luna_images/new_mask_images_0026_0353.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# working on file  ./luna_images/new_mask_images_0028_0365.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d510>])
# working on file  ./luna_images/new_mask_images_0029_0370.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0372.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0373.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0374.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0375.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0376.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0377.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0378.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0379.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0030_0380.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d490>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# working on file  ./luna_images/new_mask_images_0031_0382.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# working on file  ./luna_images/new_mask_images_0032_0395.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# working on file  ./luna_images/new_mask_images_0033_0452.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d490>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d710>])
# working on file  ./luna_images/new_mask_images_0033_0453.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d410>, <skimage.measure._regionprops._RegionProperties object at 0x11962d810>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d510>, <skimage.measure._regionprops._RegionProperties object at 0x11962d8d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962dbd0>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>])
# working on file  ./luna_images/new_mask_images_0034_0467.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d410>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962dbd0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# working on file  ./luna_images/new_mask_images_0035_0474.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# working on file  ./luna_images/new_mask_images_0036_0486.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d490>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d350>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d8d0>])
# working on file  ./luna_images/new_mask_images_0037_0508.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d510>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 8, 8, 8]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d350>, <skimage.measure._regionprops._RegionProperties object at 0x11962dbd0>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962d810>, <skimage.measure._regionprops._RegionProperties object at 0x11962d710>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>, <skimage.measure._regionprops._RegionProperties object at 0x11962d910>, <skimage.measure._regionprops._RegionProperties object at 0x11962d8d0>])
# working on file  ./luna_images/new_mask_images_0038_0511.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0038_0512.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0039_0537.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d710>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d350>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# working on file  ./luna_images/new_mask_images_0040_0542.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0040_0543.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0040_0544.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0040_0545.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0040_0546.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0041_0547.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962dbd0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d410>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d350>])
# working on file  ./luna_images/new_mask_images_0041_0548.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>, <skimage.measure._regionprops._RegionProperties object at 0x11962d910>, <skimage.measure._regionprops._RegionProperties object at 0x11962d810>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d710>])
# working on file  ./luna_images/new_mask_images_0041_0549.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d510>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# working on file  ./luna_images/new_mask_images_0043_0552.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d490>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962df90>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962dd10>])
# working on file  ./luna_images/new_mask_images_0043_0553.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d3d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>, <skimage.measure._regionprops._RegionProperties object at 0x11962d0d0>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d510>])
# working on file  ./luna_images/new_mask_images_0044_0565.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0046_0629.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129aa310>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0050_0683.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb610>])
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 1, 1, 1]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x112eb2450>])
# working on file  ./luna_images/new_mask_images_0051_0692.npy
# [ 1.  1.  1. ...,  1.  1.  1.]
# ('Labels?: ', array([1, 1, 1, ..., 2, 2, 2]))
# ('Regions: ', [<skimage.measure._regionprops._RegionProperties object at 0x1129cb250>, <skimage.measure._regionprops._RegionProperties object at 0x11962d810>])
# ...
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0012_0151.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0015_0184.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0016_0198.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0017_0233.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0017_0234.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0018_0257.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0018_0258.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0018_0259.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0019_0278.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0020_0280.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0021_0298.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0023_0314.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0023_0315.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0024_0337.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0025_0351.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0026_0352.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0026_0353.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0028_0365.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0029_0370.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0372.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0373.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0374.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0375.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0376.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0377.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0378.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0379.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0030_0380.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0031_0382.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0032_0395.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0033_0452.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0033_0453.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0034_0467.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0035_0474.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0036_0486.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0037_0508.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0038_0511.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0038_0512.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0039_0537.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0040_0542.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0040_0543.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0040_0544.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0040_0545.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0040_0546.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0041_0547.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0041_0548.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0041_0549.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0043_0552.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0043_0553.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0044_0565.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0046_0629.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0050_0683.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# working on file  ./luna_images/new_mask_masks_0051_0692.npy
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# []
# ('Labels?: ', array([], dtype=int64))
# ('Regions: ', [])
# no good regions
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
num_images = len(out_images)
print(num_images)
#
#  Writing out images and masks as 1 channel arrays for input into network
#
final_images = np.ndarray([num_images,1,512,512],dtype=np.float32)
final_masks = np.ndarray([num_images,1,512,512],dtype=np.float32)
for i in range(num_images):
    final_images[i,0] = out_images[i]
    final_masks[i,0] = out_nodemasks[i]

rand_i = np.random.choice(range(num_images),size=num_images,replace=False)
test_i = int(0.2*num_images)
np.save(working_path+"trainImages.npy",final_images[rand_i[test_i:]])
np.save(working_path+"trainMasks.npy",final_masks[rand_i[test_i:]])
np.save(working_path+"testImages.npy",final_images[rand_i[:test_i]])
np.save(working_path+"testMasks.npy",final_masks[rand_i[:test_i]])
# Out:
# 216
